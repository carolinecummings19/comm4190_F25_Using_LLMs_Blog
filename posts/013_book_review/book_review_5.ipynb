# %% [raw]
# ---
# title: "Book Reflection #5"
# description: "Superagency: What Could Possibly Go Right with Our AI Future by Reid Hoffman and Greg Beato"
# author: "Caroline Cummings"
# date: "12/14/2025"
# categories:
#   - pro-AI
#   - book review
# ---

# %% [markdown]
# # Review of *Superagency* Chapters 9-11

# %% [markdown]
# ## Chapter 9: Networked Autonomy
#
# Chapter 9 talks about how AI will support more complicated human endeavors by enhancing human agency. This teamwork will lead to even greater impact than before because of AI being a supertool. One specific concept mentioned was an "agentic AI mesh" where multiple AI agents work together without much human involvement. These autonomous systems will require good guardrails and guidelines in order to stay on track and be productive in technological innovation.
#
# ## Chapter 10: The United States of A(I)merica
#
# This chapter highlights the need for the U.S. to prioritize AI so that it can stay a world leader. The government can utilize AI to modernize their governance, improve public services, and drive economic growth. It relates AI to other national infrastructure like highways or the internet which can put the U.S. in another era of prosperity. The end of the chapter emphasizes the importance of being cautious when implementing AI in the government because of risks of job displacement, monopoly, and ethical use. The authors frame AI as a tool that America needs to invest in for the betterment of the nation.
#
# ## Chapter 11: You Can Get There from Here
#
# This chapter is a culmination of themes previously mentioned in the book. Specifically, how AI can help humans build a better future and how people should actively participate in shaping AI's trajectory. A large portion of the chapter is also on certain challenges that should be guarded against like ethical issues, amplifying inequalities, and corosion of critical thinking.
#
# ## Overall Thoughts
#
# I thought this book was an interesting read and my first book on AI. I appreaciated the historical bits where the authors looked back on certain historical events. There were a lot of claims surrounding how historical events panned out and how AI will do the same. However, these claims are very broad and some were not very similar to the current state and innovation of AI so didn't seem very meaningful.
#
# I also thought the authors were super optimist about the outcomes of the AI boom, sometimes too much so. Reid Hoffman has a unique perspective coming from being a billionaire and on the board of Microsoft which probably makes his positivity understandable. However, I think for most of the readers his broad claims of how AI will improve society and permissionless innovation will lead to safer models is not something that may resonate with the average person. Some of it seemed pretty dystopian too.
#
# I also thought this book was overly U.S. centric and also the title could be a little misleading considering it did not really talk about AI agents but rather human agency. It sort of seemed like a manifesto on adopting AI in the hopes the rapid innovation will correct any issues with current models.
#
# Overall, thought it was fairly easy to read and interesting food for thought. It definitely wasn't the greatest book I've read and I certainly did not agree with a lot in the book but not that bad.
