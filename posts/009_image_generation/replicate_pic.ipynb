# %% [raw]
# ---
# title: "Trying to Make Identical Photograph with Nano Banana"
# description: "Asking to create a realistic photograph of a Philadelphia street."
# author: "Caroline Cummings"
# date: "12/18/2025"
# categories:
#   - Philadelphia
#   - Gemini 2.5 Flash
#   - Image generation
#   - Nano Banana
# ---

# %% [markdown]
# # Recreating a Street Corner in Philadelphia
#
# I wanted to test the capabilities of Nano Banana to generate a realistic image using my description of a picture I had on my phone. Here is the reference photo:
